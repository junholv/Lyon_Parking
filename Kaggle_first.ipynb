# %% [markdown]
# Place de Parking sur Lyon dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 1051
#
#     :Number of Attributes: 24 numeric/categorical predictive. Id of all Parking (attribute 25) is usually the index.
#
#     :Attribute Information (in order):
#         - nom                Name of the parking
#         - commune            Parking's town
#         - proprietaire       Parking's Owner
#         - gestionnaire       Parking's administrator
#         - voieentree         Parking's street
#         - voiesortie         Parking's street
#         - avancement         Parking's process
#         - typeparking        Parking's type
#         - situation          Parking's status
#         - parkingtempsreel   Parking's real time
#         -gabarit             Parking's height size
#         -capacite            Parking's space
#         -capacite2rm         Parking's space for motorbike
#         -capacitevelo        Parking's space for bicycle
#         -capaciteautopartage Parking's car sharing
#         -capacitepmr         Parking's space for disabled people wishing
#         -usage               Parking's purpose
#         -vocation            Parking's goal
#         -reglementation      Parking's control
#         -fermeture           Parking's schedule
#         -fermeture           Parking's codetype
#         -gid                 Parking's group identifier
#         -gml_id              Parking's optional external group element identifier
#         -longitude           Parking's longitude
#         -latitude            Parking's latitude
#
#     :Missing Attribute Values: None
#
#     :Creator: OBO Junholv, Intern Data Scientist
#
# This is a derivated copy of GRAND LYON dataset after my cleaning.
# https://download.data.grandlyon.com/ws/grandlyon/pvo_patrimoine_voirie.pvoparking/all.json
#
# I come from Lyon, because of i like this city; i want to created something can promote thought someone who want
# improve our beautiful city.
#
# "Je viens de lyon, parce-que j'aime cette ville, je voulais créer quelque chose qui pouvait pousser à la reflexion, pour que quelqu'un autre que moi puisse toujours avoir l'idée d'améliorer notre ville."
#
#
#
# References
#
#    - Data Grand Lyon

# %%
import pandas as pd
import numpy as np

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df=pd.read_csv('Parking_Lyon_Kaggle.csv')
df.head()
# Out:
#                           nom     commune proprietaire gestionnaire  \
# 0      Parking Hôtel de Ville   Lyon 1 er   GRAND LYON          LPA
# 1            Parking Terreaux   Lyon 1 er   GRAND LYON          LPA
# 2  Parking Tables Claudiennes   Lyon 1 er   GRAND LYON          LPA
# 3              Parking Rozier   Lyon 1 er   GRAND LYON  PARTICULIER
# 4            Parking Récamier  Lyon 2 ème   GRAND LYON         SAJR
#
#                    voieentree                  voiesortie avancement  \
# 0            Quai Jean Moulin            Quai Jean Moulin   Existant
# 1               Rue d'Algérie  Rue Ste Marie des Terreaux   Existant
# 2  Rue des Tables Claudiennes  Rue des Tables Claudiennes   Existant
# 3        Rue de l'Abbé Rozier        Rue de l'Abbé Rozier   Existant
# 4              Quai Gailleton              Quai Gailleton   Existant
#
#        typeparking              situation  parkingtempsreel  gabarit  \
# ...

# %%
df.shape
# Out:
# (1051, 25)

# %%
pd.options.display.max_columns = None # me montre toutes mes columns
pd.set_option('display.max_rows', None)#me montre tout les ligne de ma column
df
# Out:
#                                                   nom  \
# 0                              Parking Hôtel de Ville
# 1                                    Parking Terreaux
# 2                          Parking Tables Claudiennes
# 3                                      Parking Rozier
# 4                                    Parking Récamier
# 5                 Parking Gare Perrache La Confluence
# 6                                      Parking Bourse
# 7                                   Parking Bellecour
# 8                                  Parking Cordeliers
# 9                                  Parking Perrache 1
# 10                                 Parking République
# 11                                  Parking Célestins
# 12                             Parking Antonin Poncet
# 13                              Parking Saint Antoine
# 14                             Parking Fosse aux Ours
# 15                                   Parking Villette
# ...

# %% [markdown]
# ### Create a pie chart presenting the reglementation proportion

# %%
# sum the instances of males and females
Parking_Payant = (df['reglementation'] == 'Payant').sum()
Parking_Gratuit = (df['reglementation'] == 'Gratuit').sum()
Parking_ZoneBleu = (df['reglementation'] == 'Zone bleue').sum()

# put them into a list called proportions
proportions = [Parking_Payant, Parking_Gratuit, Parking_ZoneBleu]

# Create a pie chart
plt.pie(
    # using proportions
    proportions,
    
    # with the labels being officer names
    labels = ['Payant', 'Gratuit','Zone bleue'],
    
    # with no shadows
    shadow = False,
    
    # with colors
    colors = ['blue','orange', 'green'],
    
    # with one slide exploded out
    explode = (0.15 , 0, 0.15 ),
    
    # with the start angle at 90%
    startangle = 90,
    
    # with the percent listed as a fraction
    autopct = '%1.1f%%'
    )

# View the plot drop above
plt.axis('equal')

# Set labels
plt.title("Reglementation Proportion",loc='left')

# View the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Here you can see 78% of parking in Lyon is free

# %% [markdown]
# ### Create a scatterplot with the Capacite and the Reglementation, we differ the plot color by gender

# %%
# creates the plot using
lm = sns.lmplot(x = 'capacitepmr', y = 'capacite', data = df, hue = 'reglementation', fit_reg=False)

# set title
lm.set(title = 'capacite x capacitepmr')

# get the axes object and tweak it
axes = lm.axes
axes[0,0].set_ylim(-5,)
axes[0,0].set_xlim(-5,40)
# Out:
# (-5, 40)

# %% [markdown]
# Strangely in lyon, when the capacity of parking shape increase, the parking become paying

# %%
# sort the values from the top to the least value and slice the first 5 items
df["capacite"] = df.capacite.sort_values(ascending = False)
df["capacite"]

# create bins interval using numpy
binsVal = np.arange(0,600,10)
binsVal

# create the plot
plt.hist(df["capacite"], bins = binsVal)

# Set the title and labels
plt.xlabel('Capacite')
plt.ylabel('Frequency')
plt.title('Capacite du Parking')

# show the plot
plt.show()

# %% [markdown]
# ### Gabarit

# %%
# create histogram
Gaba= sns.distplot(df['gabarit']);

# set lables and titles
Gaba.set(xlabel = 'Value', ylabel = 'Frequency', title = "Gabarit Total")

# take out the right and upper borders
sns.despine()

# %% [markdown]
# Here, we can say with an distribution function, the most gabarit value of all parking are around 2.00 m

# %%
sns.jointplot(x ="capacitepmr", y ="parkingtempsreel", data = df)

# %% [markdown]
# Bizzarement quand il y'a des personnes a mobilité réduite ya moins de parking en temps réel, donc difficile pour eux de savoir s'il est oui ou non occupés.
# Strangely, when we have some disabled people, we have less parking in reel time **parkingtempsreel**. And disabled people wishing can't know if they have a shape or not

# %%
#sns.pairplot(df)

# %%
sns.stripplot(x = "capacitepmr", y = "capacite", hue = "reglementation", data = df, jitter = True);

# %% [markdown]
# The same probleme, disabled people doesn't have enough parking shape, they just are lucky when other people paying, they're have juste 1 parking shape sometimes

# %%
g = sns.FacetGrid(df, col = "reglementation", hue = "usage")
g.map(plt.scatter, "capacitepmr", "capacite", alpha =1)


g.add_legend();

# %% [markdown]
# We have more parking shape for disabled people when it's free

# %%
import folium
import json

# %%
colors = {'Gratuit' : 'orange', 'Payant' : 'blue','Zone bleue':'green'}
location=[45.76848099905716,4.837471]
map_osm = folium.Map(location, zoom_start=15)

df.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]], 
                                              radius=10, fill_color=colors[row['reglementation']], popup=row['reglementation'])
                                             .add_to(map_osm), axis=1)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#     :In this map we can see all parkin, when is:
#         -Blue:   Parking is not free
#         -Orange: Parking is free
#         -Green:  Parking's zone blue

# %%
df.groupby('reglementation').size()
# Out:
# reglementation
# Gratuit       822
# Payant        170
# Zone bleue     59
# dtype: int64

# %%
# group by the Country
Parking = df.groupby('nom').sum()

# we sort the value and get the first 10 high parking shape
Parking = Parking.sort_values(by = 'capacite',ascending = False)[0:10]

# create the plot
Parking['capacite'].plot(kind='bar')

# Set the title and labels
plt.xlabel('Parking')
plt.ylabel('Capacite')
plt.title('10 Parking with more orders')

# show the plot
plt.show()

# %% [markdown]
# Here, we sort the value and get the first 10 high parking shape of Lyon

# %%
df.plot(kind="scatter", x="longitude", y="latitude")
#save_fig("bad_visualization_plot")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# Here ici all parking in lyon, we can plot it with latitude and longitude coordonates

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
            s=df["capacite"]/100, label="capacite", figsize=(10,7),
            c="capacitepmr", cmap=plt.get_cmap("jet"), colorbar=True,
            )

plt.legend()

# %% [markdown]
# ### 2. Data preprocessing
# Counting the number of missing values of each feature

# %%
df.isnull().sum()
# Out:
# nom                    0
# commune                0
# proprietaire           0
# gestionnaire           0
# voieentree             0
# voiesortie             0
# avancement             0
# typeparking            0
# situation              0
# parkingtempsreel       0
# gabarit                0
# capacite               0
# capacite2rm            0
# capacitevelo           0
# capaciteautopartage    0
# capacitepmr            0
# usage                  0
# vocation               0
# reglementation         0
# fermeture              0
# codetype               0
# gid                    0
# gml_id                 0
# longitude              0
# latitude               0
# dtype: int64

# %%
sns.set(style = 'whitegrid', context = 'notebook')
cols = ["parkingtempsreel", "gabarit", "capacite", "capacite2rm", "capacitevelo", "capaciteautopartage", "capacitepmr"]
sns.pairplot(df[cols], height = 2.5)
plt.show()

# %% [markdown]
# There is a linear relationship between **capacitevelo** (Parking's space for bicycle) and the number of places for motorbike **capacite2rm** (Parking's space for motorbike). **capacite2rm** seems to be normally distributed, but it contains outliers

# %% [markdown]
# There is a linear relationship between **capacite** (Parking's space) and the number of places for person with an handicap **capacitepmr** (Parking's space for disabled people wishing). **capaciteprm** seems to be normally distributed, but it contains outliers

# %% [markdown]
# ### Checking the linear relationships between the variables through the correlation matrix

# %%
data2 = df[["parkingtempsreel", "gabarit", "capacite", "capacite2rm", "capacitevelo", "capaciteautopartage", "capacitepmr"]]
sns.set(rc={'figure.figsize':(12,9)})

corr = data2.corr(method="pearson")
sns.heatmap(corr)

# %%
#la liste des columns que je veux corroler
data2 = df[["parkingtempsreel", "gabarit", "capacite", "capacite2rm", "capacitevelo", "capaciteautopartage", "capacitepmr"]]
# sns.reset_orig() choix de la taile d'affichage
sns.set(rc={'figure.figsize':(12,9)})
# Return Pearson product-moment correlation coefficients with values on cell 
correlation_matrix = np.corrcoef(data2.values.T)
# sns.set(font_scale = 1.5) , parametre l'affichage 
hm = sns.heatmap(data = correlation_matrix,
                 annot = True,
                 square = True,
                 fmt='.2f', #The format of the annotations inside the heatmap.
                     #This should either use the string format method, e.g.
                     #"$ {x:.2f}", or be a :class:`matplotlib.ticker.Formatter`.
                 yticklabels=data2.columns,
                 xticklabels=data2.columns)

#df.select_dtypes('number').corrwith(s)

# %% [markdown]
# * **capacite** is positively high correlated with **capacitepmr**(0.7),
# * Features **capacite2rm** and **capaciteautopartage** are good correlated to each other (0.60). Thus, we should not select these feature together to train the model. The same are valid for features **gabarit** and **parkingtempsreel**
#
# Let's investigate how **capacite2rm* and **capaciteautopartage** vary with **capacitevelo**

# %%
plt.figure(figsize=(20,5))

features = ['capacitepmr', 'capaciteautopartage']

for i, col in enumerate(features):
    plt.subplot(1, len(features), i + 1)
    plt.scatter(df[col], df['capacite'])
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('capacite')

# %% [markdown]
# * The Parking's car sharing(**capacitepmr**) increases. Therefore, there are some outliers
# * Parking's space for bicycle (**capaciteautopartage**) increases, Although it does not seem to follows a linear relationship

# %% [markdown]
# # Implementing an ordinary least squares (OLS)

# %% [markdown]
# ## Estimating the parameters $\beta{}$ using sum of squared residuals (SSR), computed as:
#
# $$RSS(\beta{}) = \min_{\beta{}\in{}\mathbb{R}} \sum_{i=1}^{N}{(y_i - x_i^T\beta{})^2}$$

# %%
class LinearRegressionGD(object):
    
    def __init__(self, alpha=0.001, n_iter=20):
        self.alpha = alpha
        self.n_iter = n_iter
    
    def fit(self, X, y):
        self.beta_ = np.zeros(1 + X.shape[1])
        self.cost_ = [] 
        
        for i in range(self.n_iter):
            output = self.net_input(X)
            errors = (y - output)
            self.beta_[1:] += self.alpha * X.T.dot(errors)
            self.beta_[0]  += self.alpha * errors.sum()
            cost = (errors ** 2).sum() / 2.0
            self.cost_.append(cost)
        return self
    
    def net_input(self, X):
        return np.dot(X, self.beta_[1:]) + self.beta_[0]
    
    def predict(self, X):
        return self.net_input(X)

# %%
X = df[['capacitepmr']].values
y = df['capacite'].values

from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()

X_std = sc_x.fit_transform(X)
y_std = sc_y.fit_transform(y[:, np.newaxis]).flatten()
# Out:
# /Users/Administrateur/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Administrateur/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Administrateur/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/Administrateur/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Creating the model

# %%
lr_model = LinearRegressionGD()
lr_model.fit(X_std, y_std)

# %% [markdown]
# ### Checking the space as a function of the number of epochs

# %%
# sns.reset_orig()
plt.figure(figsize=(4,3))
plt.plot(range(1, lr_model.n_iter+1), lr_model.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.tight_layout()

# %% [markdown]
# As can be seen, the gradient descent algorithm converged nearly after the third epoch

# %% [markdown]
# ### Checking how well the linear regression model fits the training data

# %%
def lin_regplot(X, y, model, xlabel='', ylabel=''):
    plt.scatter(X, y, c='blue')
    plt.plot(X, model.predict(X), color='red')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    return None

plt.figure(figsize=(5,3))
lin_regplot(X_std, y_std, lr_model, xlabel = 'capacitepmr (standardized)', ylabel = 'capacite (standardized)')

# %% [markdown]
# * It seems that only the number after 10 square space for capacite is insufficient to explain the why desabled people have not her in different cases.
# * Likewise, the data suggest thatspace may have been clipped. Thus, let's scale the predicted space outcome back on the space in 5 axis, using the **inverse_transform** method of the **_StandardScaler_**

# %%
num_space_std = sc_x.transform(np.array([[5.0]]))
# using the trained model to predict the space after five space.
space_std = lr_model.predict(num_space_std) 

print("Space in 5 square: %.3f" % sc_y.inverse_transform(space_std))
# Out:
# Space in 5 square: 364.099

# %%
print('Slope: %.3f' %lr_model.beta_[1])
print('Intercept: %.3f' %lr_model.beta_[0])
# Out:
# Slope: 0.726
# Intercept: -0.000

# %% [markdown]
# # Using scikit-learn to estimates the parameters

# %%
from sklearn.linear_model import LinearRegression

lmodel = LinearRegression()
lmodel.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('Slope: %.3f' %lmodel.coef_[0], '\nIntercept: %.3f' % lmodel.intercept_)
# Out:
# Slope: 69.772
# Intercept: 15.240

# %%
plt.figure(figsize=(5,3))
lin_regplot(X, y, lmodel, 'capacitepmr', 'capacite')

# %% [markdown]
# # Using RANdom SAmple Consensus (RANSAC) algorithm to fit a robust regression model

# %% [markdown]
# The RANSAC algorithm fits a regression model to a subset of data, aka _inliers_.
#
# It can be summarized as follows:
#
# 1. Select a random number of samples to be inliers and fit the model.
# 2. Test all other data points against the fitted model and those points that fall within a user-given tolerance to the inliers.
# 3. Refit the model using all the inliers.
# 4. Estimate the error of the fitted model versus the inliers.
# 5. Terminate if the performance meets a certain user-defined threshold of if a fixed number of iterations has been reached. Otherwise, returns to step 1.

# %%
from sklearn.linear_model import RANSACRegressor

ransac = RANSACRegressor(base_estimator=LinearRegression(), 
                         max_trials=100, 
                         min_samples=50, 
                         residual_threshold=5.0, 
                         random_state=10)
ransac.fit(X,y)
# Out:
# RANSACRegressor(base_estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#         is_data_valid=None, is_model_valid=None, loss='absolute_loss',
#         max_skips=inf, max_trials=100, min_samples=50, random_state=10,
#         residual_threshold=5.0, stop_n_inliers=inf, stop_probability=0.99,
#         stop_score=inf)

# %%
inlier_mask = ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)
line_X = np.arange(3,10, 1)
line_y_ransac = ransac.predict(line_X[:, np.newaxis])

plt.figure(figsize=(10,7))
plt.scatter(X[inlier_mask], y[inlier_mask], c='blue', label = 'Inliers')
plt.scatter(X[outlier_mask], y[outlier_mask], c='green', label='Outliers', marker='s')
plt.plot(line_X, line_y_ransac, color='red')
plt.xlabel('capacitepmr')
plt.ylabel('capacite')
plt.legend(loc='lower right')

print('Slope: %.3f' %ransac.estimator_.coef_[0], '\nIntercept: %.3f' %ransac.estimator_.intercept_)
# Out:
# Slope: 26.739
# Intercept: 26.622

# %% [markdown]
# # Evaluating the performance of linear models

# %% [markdown]
# ## Splitting the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

X = pd.DataFrame(np.c_[df['capaciteautopartage'], df['capacitepmr']], columns = ['capaciteautopartage','capacitepmr'])
Y = df['capacite']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .2, random_state = 10)

print("X_train = ", X_train.shape, "X_test = ", X_test.shape, 
      "Y_train = ", Y_train.shape, "Y_test=",   Y_test.shape)
# Out:
# X_train =  (840, 2) X_test =  (211, 2) Y_train =  (840,) Y_test= (211,)

# %% [markdown]
# Creating the linear model

# %%
lmodel = LinearRegression()
lmodel.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ## Evaluating the model

# %%
y_train_predicted = lmodel.predict(X_train)
y_test_predicted  = lmodel.predict(X_test)

# %% [markdown]
# ### Checking the residuals

# %%
plt.figure(figsize=(6,5))
plt.scatter(y_train_predicted, y_train_predicted - Y_train, c='blue', label='Training data')
plt.scatter(y_test_predicted, y_test_predicted - Y_test, c='green', marker='s', label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.hlines(y=0, xmin=-10, xmax=50, lw=2, color='red')
plt.xlim([-10,50])
plt.ylim([-30,20])
plt.legend(loc='upper left')

# %% [markdown]
# * The model seem to be completely an horor, as the residuals are randomly scattered around 0 y-axis.
# * Therefore, the model is unable to capture some exploratory information, as can be seen in the presence of right around 0

# %% [markdown]
# ### Computing the MSE, RMSE, and $R^2$
#
# * The **mean square error (MSE)** is simply the average value of the **residual sum of squares (RSS)** that we minimize to fit the linear regression model.
#
# $$MSE = \frac{1}{N}\sum_{i=1}^{N}(y_i - \hat{y_i})^2$$
#
# * The **root mean square error (RMSE)** comprises the standard deviation of the residuals. It tells us how concentrated the data are around the line of the best fit.
#
# $$RMSE = \sqrt{MSE}$$
#
# * The coefficient of determination ($R^2$) represents the fraction of response variance that is captured by the model. It is computed as follows:
#
# $$ R^2 = 1 - \frac{MSE}{Var(y)}$$
#
# For the training dataset, $R^2$ is bounded between 0 and 1. Therefore, it can become negative for the test set. If $R^2 = 1$, the model fits the data perfectly, which corresponde a $MSE = 0$.

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse_train = mean_squared_error(Y_train, y_train_predicted)
mse_test = mean_squared_error(Y_test, y_test_predicted)

print('MSE train: %.3f, test: %.3f' %(mse_train, mse_test))
print('RMSE train: %.3f, RMSE test: %.3f' % (np.sqrt(mse_train), np.sqrt(mse_test)))

print('R2 score train: %.3f, R2 score test: %.3f' %(r2_score(Y_train, y_train_predicted), 
                                                    r2_score(Y_test, y_test_predicted)))
# Out:
# MSE train: 99059.400, test: 99892.207
# RMSE train: 314.737, RMSE test: 316.057
# R2 score train: 0.601, R2 score test: -0.017

# %% [markdown]
# # To conclude,
# ### In lyon, every parking needs for disabled people to create more parking shape or equalize that with the same numbers of parking shape's motorbike.
